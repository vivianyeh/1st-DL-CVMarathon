# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 4s 2ms/step - loss: 0.0058 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00207, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00207 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 499us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00185
# Epoch 5/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00180, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 8.9867e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00180 to 0.00170, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 499us/step - loss: 7.6037e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00170 to 0.00147, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 496us/step - loss: 6.6866e-04 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00147 to 0.00133, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 500us/step - loss: 5.9785e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00133 to 0.00127, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 497us/step - loss: 5.3334e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00127 to 0.00116, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 4.8157e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00116 to 0.00109, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 4.5074e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss did not improve from 0.00109
# Epoch 13/150
# 1712/1712 [==============================] - 1s 500us/step - loss: 4.1945e-04 - val_loss: 9.9935e-04
#
# Epoch 00013: val_loss improved from 0.00109 to 0.00100, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 3.9631e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss did not improve from 0.00100
# Epoch 15/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 3.7140e-04 - val_loss: 9.3748e-04
#
# Epoch 00015: val_loss improved from 0.00100 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 3.5432e-04 - val_loss: 9.3631e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 497us/step - loss: 3.4022e-04 - val_loss: 9.3871e-04
#
# Epoch 00017: val_loss did not improve from 0.00094
# Epoch 18/150
# 1712/1712 [==============================] - 1s 500us/step - loss: 3.2813e-04 - val_loss: 9.4239e-04
#
# Epoch 00018: val_loss did not improve from 0.00094
# Epoch 19/150
# 1712/1712 [==============================] - 1s 491us/step - loss: 3.2446e-04 - val_loss: 8.4671e-04
#
# Epoch 00019: val_loss improved from 0.00094 to 0.00085, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 3.0607e-04 - val_loss: 8.7008e-04
#
# Epoch 00020: val_loss did not improve from 0.00085
# Epoch 21/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 2.9304e-04 - val_loss: 8.7377e-04
#
# Epoch 00021: val_loss did not improve from 0.00085
# Epoch 22/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 2.9316e-04 - val_loss: 8.5252e-04
#
# Epoch 00022: val_loss did not improve from 0.00085
# Epoch 23/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.7847e-04 - val_loss: 8.9057e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 2.6865e-04 - val_loss: 8.4260e-04
#
# Epoch 00024: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 2.6397e-04 - val_loss: 8.1318e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 2.5835e-04 - val_loss: 8.3257e-04
#
# Epoch 00026: val_loss did not improve from 0.00081
# Epoch 27/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 2.5599e-04 - val_loss: 8.0137e-04
#
# Epoch 00027: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.5199e-04 - val_loss: 8.8530e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.4025e-04 - val_loss: 8.0012e-04
#
# Epoch 00029: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.3229e-04 - val_loss: 7.9431e-04
#
# Epoch 00030: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 1s 500us/step - loss: 2.3232e-04 - val_loss: 8.2789e-04
#
# Epoch 00031: val_loss did not improve from 0.00079
# Epoch 32/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.3045e-04 - val_loss: 8.0154e-04
#
# Epoch 00032: val_loss did not improve from 0.00079
# Epoch 33/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.2192e-04 - val_loss: 7.7989e-04
#
# Epoch 00033: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 2.1216e-04 - val_loss: 7.8352e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 2.1106e-04 - val_loss: 8.3018e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 2.1114e-04 - val_loss: 8.2816e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.0390e-04 - val_loss: 8.0824e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.0143e-04 - val_loss: 8.3277e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.9953e-04 - val_loss: 7.6998e-04
#
# Epoch 00039: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 1.9257e-04 - val_loss: 7.8315e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.9540e-04 - val_loss: 7.9656e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 1.8943e-04 - val_loss: 7.9322e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 1.8677e-04 - val_loss: 7.7538e-04
#
# Epoch 00043: val_loss did not improve from 0.00077
# Epoch 44/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.8229e-04 - val_loss: 7.8186e-04
#
# Epoch 00044: val_loss did not improve from 0.00077
# Epoch 45/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.8957e-04 - val_loss: 7.9374e-04
#
# Epoch 00045: val_loss did not improve from 0.00077
# Epoch 46/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.8250e-04 - val_loss: 8.4196e-04
#
# Epoch 00046: val_loss did not improve from 0.00077
# Epoch 47/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.7915e-04 - val_loss: 7.8594e-04
#
# Epoch 00047: val_loss did not improve from 0.00077
# Epoch 48/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.7412e-04 - val_loss: 7.8997e-04
#
# Epoch 00048: val_loss did not improve from 0.00077
# Epoch 49/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.7276e-04 - val_loss: 8.1914e-04
#
# Epoch 00049: val_loss did not improve from 0.00077
# Epoch 50/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.6826e-04 - val_loss: 8.2028e-04
#
# Epoch 00050: val_loss did not improve from 0.00077
# Epoch 51/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 1.6872e-04 - val_loss: 7.8281e-04
#
# Epoch 00051: val_loss did not improve from 0.00077
# Epoch 52/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.6207e-04 - val_loss: 7.7919e-04
#
# Epoch 00052: val_loss did not improve from 0.00077
# Epoch 53/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 1.6514e-04 - val_loss: 7.6698e-04
#
# Epoch 00053: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.5871e-04 - val_loss: 7.5707e-04
#
# Epoch 00054: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 55/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 1.5982e-04 - val_loss: 7.9245e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.5840e-04 - val_loss: 7.8385e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 1.5627e-04 - val_loss: 7.6902e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 1s 519us/step - loss: 1.5757e-04 - val_loss: 7.7821e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.5508e-04 - val_loss: 7.5373e-04
#
# Epoch 00059: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.5394e-04 - val_loss: 7.8825e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 1s 524us/step - loss: 1.5175e-04 - val_loss: 7.9848e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 1s 522us/step - loss: 1.5216e-04 - val_loss: 7.9895e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 1s 519us/step - loss: 1.4905e-04 - val_loss: 7.9638e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.4867e-04 - val_loss: 8.1901e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 1s 518us/step - loss: 1.4830e-04 - val_loss: 7.7902e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 1s 519us/step - loss: 1.4157e-04 - val_loss: 7.8181e-04
#
# Epoch 00066: val_loss did not improve from 0.00075
# Epoch 67/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.4261e-04 - val_loss: 7.9525e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 1.4115e-04 - val_loss: 7.6235e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.3601e-04 - val_loss: 7.6914e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.3482e-04 - val_loss: 7.9527e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 1s 525us/step - loss: 1.4033e-04 - val_loss: 7.6368e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 1.3502e-04 - val_loss: 7.5830e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.3276e-04 - val_loss: 7.8693e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 1.3130e-04 - val_loss: 7.5237e-04
#
# Epoch 00074: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 75/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.3005e-04 - val_loss: 7.7909e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.2877e-04 - val_loss: 7.8169e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 1.2815e-04 - val_loss: 8.1967e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.2859e-04 - val_loss: 7.6069e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.2420e-04 - val_loss: 7.7973e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 1s 520us/step - loss: 1.2775e-04 - val_loss: 7.8885e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.2665e-04 - val_loss: 7.5801e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.2419e-04 - val_loss: 7.4372e-04
#
# Epoch 00082: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 83/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.2437e-04 - val_loss: 7.7495e-04
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 1712/1712 [==============================] - 1s 520us/step - loss: 1.2528e-04 - val_loss: 8.0965e-04
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.2181e-04 - val_loss: 7.4341e-04
#
# Epoch 00085: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 86/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.2125e-04 - val_loss: 7.6061e-04
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.2047e-04 - val_loss: 7.6677e-04
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 1.1920e-04 - val_loss: 7.7426e-04
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 1712/1712 [==============================] - 1s 518us/step - loss: 1.1479e-04 - val_loss: 7.8708e-04
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.2008e-04 - val_loss: 8.0845e-04
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 1712/1712 [==============================] - 1s 518us/step - loss: 1.2258e-04 - val_loss: 7.7917e-04
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.1410e-04 - val_loss: 7.5634e-04
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 1.1386e-04 - val_loss: 7.8012e-04
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.1927e-04 - val_loss: 7.8731e-04
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 1.1312e-04 - val_loss: 7.7902e-04
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.1190e-04 - val_loss: 7.7062e-04
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.1667e-04 - val_loss: 7.7862e-04
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.1122e-04 - val_loss: 7.8739e-04
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.1335e-04 - val_loss: 8.1416e-04
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.1057e-04 - val_loss: 7.8034e-04
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 1.1110e-04 - val_loss: 7.7751e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.0868e-04 - val_loss: 8.0032e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 1.0454e-04 - val_loss: 7.6516e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.0740e-04 - val_loss: 7.9189e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.0932e-04 - val_loss: 8.1395e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.0674e-04 - val_loss: 7.8763e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.0597e-04 - val_loss: 7.7829e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.0561e-04 - val_loss: 7.8255e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 1.0345e-04 - val_loss: 7.8291e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 1.0286e-04 - val_loss: 7.7752e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 1.0134e-04 - val_loss: 7.8420e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 1.0010e-04 - val_loss: 7.9213e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.0001e-04 - val_loss: 8.1367e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.0315e-04 - val_loss: 7.6315e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 9.8211e-05 - val_loss: 7.7830e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 1.0110e-04 - val_loss: 7.6326e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 9.8661e-05 - val_loss: 7.7674e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 9.5996e-05 - val_loss: 7.8648e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 9.8533e-05 - val_loss: 8.0623e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 9.7164e-05 - val_loss: 7.9590e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 9.5386e-05 - val_loss: 7.7630e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 9.4246e-05 - val_loss: 7.9819e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 9.4212e-05 - val_loss: 8.3283e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 9.1820e-05 - val_loss: 8.1217e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 9.4186e-05 - val_loss: 8.1083e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 9.0989e-05 - val_loss: 8.0972e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 9.4303e-05 - val_loss: 8.0316e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 9.0990e-05 - val_loss: 8.3790e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 9.4010e-05 - val_loss: 7.9240e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 8.9465e-05 - val_loss: 7.9062e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 8.7048e-05 - val_loss: 8.0139e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 8.7961e-05 - val_loss: 7.8879e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 8.8837e-05 - val_loss: 8.4508e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 9.0901e-05 - val_loss: 7.7976e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 9.1151e-05 - val_loss: 7.9118e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 8.8252e-05 - val_loss: 7.8082e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 8.5855e-05 - val_loss: 7.7872e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 8.8293e-05 - val_loss: 7.7655e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 1s 522us/step - loss: 8.4812e-05 - val_loss: 7.7294e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 1s 524us/step - loss: 8.5549e-05 - val_loss: 7.7466e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 1s 516us/step - loss: 8.2167e-05 - val_loss: 8.0715e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 8.3815e-05 - val_loss: 7.9498e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 8.4220e-05 - val_loss: 8.2406e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 8.3115e-05 - val_loss: 7.8455e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 8.1089e-05 - val_loss: 8.1581e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 8.1973e-05 - val_loss: 8.0808e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 8.2304e-05 - val_loss: 8.0725e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 8.2851e-05 - val_loss: 8.1085e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 8.1519e-05 - val_loss: 7.8198e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 8.1699e-05 - val_loss: 8.1649e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
new_image = np.copy(imgs_train[0])
for i in range(96):
    for j in range(96):
        new_image[i][j] =imgs_train[0][i][95-j]
plt.imshow(new_image, cmap='gray')

new_point = np.copy(points_train[0])
for i in range(0,len(new_point),2):
    new_point[i] = -1*new_point[i]
    
for i in range(0,len(new_point),2):
    plt.scatter((new_point[i]+0.5)*96, (new_point[i+1]+0.5)*96, c = 'red')
    plt.imshow(new_image, cmap='gray')

# %%
def img_aug(img, point):
    new_image = np.copy(img)
    for i in range(96):
        for j in range(96):
            new_image[i][j] =img[i][95-j]
    new_point = np.copy(point)
    for i in range(0,len(new_point),2):
        new_point[i] = -1*new_point[i]
    return new_image, new_point

# %%
new_img_train=[]
# np.copy(imgs_train)
new_point_train=[]
# np.copy(points_train)
for i in range(imgs_train.shape[0]):
    img = imgs_train[i]
    point = points_train[i]
    new_img, new_point = img_aug(img, point)
#     new_img_train[i] = new_img
    new_img_train.append(new_img)
    #     new_point_train[i] = new_point
    new_point_train.append(new_point)
new_img_train = np.array(new_img_train)
new_point_train = np.array(new_point_train)

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
hist_model = model.fit(new_img_train.reshape(-1, 96, 96, 1), 
                       new_point_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 1s 574us/step - loss: 0.0156 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00212, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00212 to 0.00192, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00192 to 0.00190, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00190
# Epoch 5/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00190
# Epoch 7/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00007: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00008: val_loss improved from 0.00189 to 0.00188, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 0.0010 - val_loss: 0.0020
#
# Epoch 00009: val_loss did not improve from 0.00188
# Epoch 10/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 0.0010 - val_loss: 0.0019
#
# Epoch 00010: val_loss improved from 0.00188 to 0.00185, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 9.9325e-04 - val_loss: 0.0018
#
# Epoch 00011: val_loss improved from 0.00185 to 0.00182, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 9.6331e-04 - val_loss: 0.0018
#
# Epoch 00012: val_loss did not improve from 0.00182
# Epoch 13/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 9.2460e-04 - val_loss: 0.0018
#
# Epoch 00013: val_loss improved from 0.00182 to 0.00182, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 8.8698e-04 - val_loss: 0.0018
#
# Epoch 00014: val_loss improved from 0.00182 to 0.00178, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 8.4842e-04 - val_loss: 0.0017
#
# Epoch 00015: val_loss improved from 0.00178 to 0.00174, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 499us/step - loss: 7.9835e-04 - val_loss: 0.0016
#
# Epoch 00016: val_loss improved from 0.00174 to 0.00163, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 7.5297e-04 - val_loss: 0.0016
#
# Epoch 00017: val_loss did not improve from 0.00163
# Epoch 18/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 7.2019e-04 - val_loss: 0.0016
#
# Epoch 00018: val_loss improved from 0.00163 to 0.00158, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 6.8626e-04 - val_loss: 0.0015
#
# Epoch 00019: val_loss improved from 0.00158 to 0.00147, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 6.5471e-04 - val_loss: 0.0015
#
# Epoch 00020: val_loss did not improve from 0.00147
# Epoch 21/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 6.2417e-04 - val_loss: 0.0015
#
# Epoch 00021: val_loss improved from 0.00147 to 0.00146, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 6.1068e-04 - val_loss: 0.0014
#
# Epoch 00022: val_loss improved from 0.00146 to 0.00138, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 5.8880e-04 - val_loss: 0.0013
#
# Epoch 00023: val_loss improved from 0.00138 to 0.00133, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 5.5829e-04 - val_loss: 0.0013
#
# Epoch 00024: val_loss improved from 0.00133 to 0.00132, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 494us/step - loss: 5.4624e-04 - val_loss: 0.0013
#
# Epoch 00025: val_loss improved from 0.00132 to 0.00128, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 5.3272e-04 - val_loss: 0.0013
#
# Epoch 00026: val_loss improved from 0.00128 to 0.00128, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 5.0783e-04 - val_loss: 0.0013
#
# Epoch 00027: val_loss did not improve from 0.00128
# Epoch 28/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 5.0892e-04 - val_loss: 0.0013
#
# Epoch 00028: val_loss improved from 0.00128 to 0.00127, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 5.0055e-04 - val_loss: 0.0013
#
# Epoch 00029: val_loss did not improve from 0.00127
# Epoch 30/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 4.9080e-04 - val_loss: 0.0012
#
# Epoch 00030: val_loss improved from 0.00127 to 0.00124, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 4.7214e-04 - val_loss: 0.0012
#
# Epoch 00031: val_loss did not improve from 0.00124
# Epoch 32/150
# 1712/1712 [==============================] - 1s 520us/step - loss: 4.6894e-04 - val_loss: 0.0013
#
# Epoch 00032: val_loss did not improve from 0.00124
# Epoch 33/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 4.5417e-04 - val_loss: 0.0012
#
# Epoch 00033: val_loss improved from 0.00124 to 0.00123, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 4.4632e-04 - val_loss: 0.0012
#
# Epoch 00034: val_loss improved from 0.00123 to 0.00120, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 4.2981e-04 - val_loss: 0.0012
#
# Epoch 00035: val_loss did not improve from 0.00120
# Epoch 36/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 4.2636e-04 - val_loss: 0.0012
#
# Epoch 00036: val_loss did not improve from 0.00120
# Epoch 37/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 4.2939e-04 - val_loss: 0.0012
#
# Epoch 00037: val_loss improved from 0.00120 to 0.00119, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 1s 497us/step - loss: 4.0773e-04 - val_loss: 0.0012
#
# Epoch 00038: val_loss did not improve from 0.00119
# Epoch 39/150
# 1712/1712 [==============================] - 1s 518us/step - loss: 4.0057e-04 - val_loss: 0.0012
#
# Epoch 00039: val_loss improved from 0.00119 to 0.00118, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 3.8582e-04 - val_loss: 0.0012
#
# Epoch 00040: val_loss improved from 0.00118 to 0.00118, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 3.9586e-04 - val_loss: 0.0012
#
# Epoch 00041: val_loss did not improve from 0.00118
# Epoch 42/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 3.7631e-04 - val_loss: 0.0012
#
# Epoch 00042: val_loss improved from 0.00118 to 0.00116, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 3.8692e-04 - val_loss: 0.0012
#
# Epoch 00043: val_loss did not improve from 0.00116
# Epoch 44/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 3.8289e-04 - val_loss: 0.0012
#
# Epoch 00044: val_loss improved from 0.00116 to 0.00116, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 3.7866e-04 - val_loss: 0.0012
#
# Epoch 00045: val_loss did not improve from 0.00116
# Epoch 46/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 3.6567e-04 - val_loss: 0.0012
#
# Epoch 00046: val_loss did not improve from 0.00116
# Epoch 47/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 3.7000e-04 - val_loss: 0.0011
#
# Epoch 00047: val_loss improved from 0.00116 to 0.00114, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 1s 500us/step - loss: 3.5511e-04 - val_loss: 0.0011
#
# Epoch 00048: val_loss improved from 0.00114 to 0.00113, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 3.5407e-04 - val_loss: 0.0012
#
# Epoch 00049: val_loss did not improve from 0.00113
# Epoch 50/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 3.4518e-04 - val_loss: 0.0011
#
# Epoch 00050: val_loss improved from 0.00113 to 0.00112, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 3.4957e-04 - val_loss: 0.0012
#
# Epoch 00051: val_loss did not improve from 0.00112
# Epoch 52/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 3.3213e-04 - val_loss: 0.0011
#
# Epoch 00052: val_loss did not improve from 0.00112
# Epoch 53/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 3.3515e-04 - val_loss: 0.0012
#
# Epoch 00053: val_loss did not improve from 0.00112
# Epoch 54/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 3.1354e-04 - val_loss: 0.0011
#
# Epoch 00054: val_loss did not improve from 0.00112
# Epoch 55/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 3.2473e-04 - val_loss: 0.0012
#
# Epoch 00055: val_loss did not improve from 0.00112
# Epoch 56/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 3.2998e-04 - val_loss: 0.0012
#
# Epoch 00056: val_loss did not improve from 0.00112
# Epoch 57/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 3.1470e-04 - val_loss: 0.0011
#
# Epoch 00057: val_loss improved from 0.00112 to 0.00111, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 1s 499us/step - loss: 3.1424e-04 - val_loss: 0.0011
#
# Epoch 00058: val_loss did not improve from 0.00111
# Epoch 59/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 3.1132e-04 - val_loss: 0.0011
#
# Epoch 00059: val_loss did not improve from 0.00111
# Epoch 60/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 3.0546e-04 - val_loss: 0.0012
#
# Epoch 00060: val_loss did not improve from 0.00111
# Epoch 61/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.9942e-04 - val_loss: 0.0011
#
# Epoch 00061: val_loss improved from 0.00111 to 0.00108, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 1s 497us/step - loss: 2.9377e-04 - val_loss: 0.0011
#
# Epoch 00062: val_loss did not improve from 0.00108
# Epoch 63/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 2.9077e-04 - val_loss: 0.0011
#
# Epoch 00063: val_loss did not improve from 0.00108
# Epoch 64/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.9053e-04 - val_loss: 0.0011
#
# Epoch 00064: val_loss did not improve from 0.00108
# Epoch 65/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.8793e-04 - val_loss: 0.0011
#
# Epoch 00065: val_loss did not improve from 0.00108
# Epoch 66/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 2.9628e-04 - val_loss: 0.0011
#
# Epoch 00066: val_loss did not improve from 0.00108
# Epoch 67/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 2.8698e-04 - val_loss: 0.0011
#
# Epoch 00067: val_loss did not improve from 0.00108
# Epoch 68/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.8651e-04 - val_loss: 0.0011
#
# Epoch 00068: val_loss did not improve from 0.00108
# Epoch 69/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.7053e-04 - val_loss: 0.0011
#
# Epoch 00069: val_loss did not improve from 0.00108
# Epoch 70/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 2.7561e-04 - val_loss: 0.0011
#
# Epoch 00070: val_loss did not improve from 0.00108
# Epoch 71/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 2.7158e-04 - val_loss: 0.0011
#
# Epoch 00071: val_loss did not improve from 0.00108
# Epoch 72/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 2.7573e-04 - val_loss: 0.0011
#
# Epoch 00072: val_loss did not improve from 0.00108
# Epoch 73/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.7165e-04 - val_loss: 0.0011
#
# Epoch 00073: val_loss did not improve from 0.00108
# Epoch 74/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.7052e-04 - val_loss: 0.0011
#
# Epoch 00074: val_loss did not improve from 0.00108
# Epoch 75/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.6798e-04 - val_loss: 0.0011
#
# Epoch 00075: val_loss did not improve from 0.00108
# Epoch 76/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 2.6367e-04 - val_loss: 0.0011
#
# Epoch 00076: val_loss did not improve from 0.00108
# Epoch 77/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 2.6116e-04 - val_loss: 0.0011
#
# Epoch 00077: val_loss did not improve from 0.00108
# Epoch 78/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 2.6110e-04 - val_loss: 0.0011
#
# Epoch 00078: val_loss did not improve from 0.00108
# Epoch 79/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 2.5377e-04 - val_loss: 0.0011
#
# Epoch 00079: val_loss did not improve from 0.00108
# Epoch 80/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 2.5466e-04 - val_loss: 0.0011
#
# Epoch 00080: val_loss did not improve from 0.00108
# Epoch 81/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.5400e-04 - val_loss: 0.0012
#
# Epoch 00081: val_loss did not improve from 0.00108
# Epoch 82/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 2.5481e-04 - val_loss: 0.0011
#
# Epoch 00082: val_loss did not improve from 0.00108
# Epoch 83/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 2.5316e-04 - val_loss: 0.0011
#
# Epoch 00083: val_loss did not improve from 0.00108
# Epoch 84/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.3977e-04 - val_loss: 0.0011
#
# Epoch 00084: val_loss did not improve from 0.00108
# Epoch 85/150
# 1712/1712 [==============================] - 1s 498us/step - loss: 2.4484e-04 - val_loss: 0.0011
#
# Epoch 00085: val_loss did not improve from 0.00108
# Epoch 86/150
# 1712/1712 [==============================] - 1s 519us/step - loss: 2.5062e-04 - val_loss: 0.0011
#
# Epoch 00086: val_loss did not improve from 0.00108
# Epoch 87/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 2.4567e-04 - val_loss: 0.0011
#
# Epoch 00087: val_loss did not improve from 0.00108
# Epoch 88/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 2.4715e-04 - val_loss: 0.0011
#
# Epoch 00088: val_loss did not improve from 0.00108
# Epoch 89/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.4595e-04 - val_loss: 0.0011
#
# Epoch 00089: val_loss did not improve from 0.00108
# Epoch 90/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 2.3545e-04 - val_loss: 0.0011
#
# Epoch 00090: val_loss did not improve from 0.00108
# Epoch 91/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 2.3956e-04 - val_loss: 0.0011
#
# Epoch 00091: val_loss did not improve from 0.00108
# Epoch 92/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.3167e-04 - val_loss: 0.0011
#
# Epoch 00092: val_loss did not improve from 0.00108
# Epoch 93/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.3134e-04 - val_loss: 0.0011
#
# Epoch 00093: val_loss improved from 0.00108 to 0.00108, saving model to best_weights.h5
# Epoch 94/150
# 1712/1712 [==============================] - 1s 499us/step - loss: 2.3501e-04 - val_loss: 0.0011
#
# Epoch 00094: val_loss did not improve from 0.00108
# Epoch 95/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.2636e-04 - val_loss: 0.0011
#
# Epoch 00095: val_loss did not improve from 0.00108
# Epoch 96/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 2.2944e-04 - val_loss: 0.0011
#
# Epoch 00096: val_loss did not improve from 0.00108
# Epoch 97/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.2454e-04 - val_loss: 0.0011
#
# Epoch 00097: val_loss did not improve from 0.00108
# Epoch 98/150
# 1712/1712 [==============================] - 1s 501us/step - loss: 2.2365e-04 - val_loss: 0.0011
#
# Epoch 00098: val_loss did not improve from 0.00108
# Epoch 99/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 2.2465e-04 - val_loss: 0.0011
#
# Epoch 00099: val_loss improved from 0.00108 to 0.00106, saving model to best_weights.h5
# Epoch 100/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.2789e-04 - val_loss: 0.0011
#
# Epoch 00100: val_loss did not improve from 0.00106
# Epoch 101/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 2.1658e-04 - val_loss: 0.0011
#
# Epoch 00101: val_loss did not improve from 0.00106
# Epoch 102/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 2.1968e-04 - val_loss: 0.0011
#
# Epoch 00102: val_loss did not improve from 0.00106
# Epoch 103/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 2.1395e-04 - val_loss: 0.0011
#
# Epoch 00103: val_loss did not improve from 0.00106
# Epoch 104/150
# 1712/1712 [==============================] - 1s 514us/step - loss: 2.1227e-04 - val_loss: 0.0011
#
# Epoch 00104: val_loss did not improve from 0.00106
# Epoch 105/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.1061e-04 - val_loss: 0.0011
#
# Epoch 00105: val_loss did not improve from 0.00106
# Epoch 106/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 2.1037e-04 - val_loss: 0.0011
#
# Epoch 00106: val_loss did not improve from 0.00106
# Epoch 107/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 2.1187e-04 - val_loss: 0.0011
#
# Epoch 00107: val_loss did not improve from 0.00106
# Epoch 108/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 2.0717e-04 - val_loss: 0.0011
#
# Epoch 00108: val_loss did not improve from 0.00106
# Epoch 109/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 2.0945e-04 - val_loss: 0.0011
#
# Epoch 00109: val_loss did not improve from 0.00106
# Epoch 110/150
# 1712/1712 [==============================] - 1s 517us/step - loss: 2.0506e-04 - val_loss: 0.0011
#
# Epoch 00110: val_loss did not improve from 0.00106
# Epoch 111/150
# 1712/1712 [==============================] - 1s 512us/step - loss: 2.0237e-04 - val_loss: 0.0011
#
# Epoch 00111: val_loss did not improve from 0.00106
# Epoch 112/150
# 1712/1712 [==============================] - 1s 508us/step - loss: 2.0609e-04 - val_loss: 0.0011
#
# Epoch 00112: val_loss improved from 0.00106 to 0.00106, saving model to best_weights.h5
# Epoch 113/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 2.0992e-04 - val_loss: 0.0011
#
# Epoch 00113: val_loss did not improve from 0.00106
# Epoch 114/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.0092e-04 - val_loss: 0.0011
#
# Epoch 00114: val_loss did not improve from 0.00106
# Epoch 115/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.0026e-04 - val_loss: 0.0011
#
# Epoch 00115: val_loss did not improve from 0.00106
# Epoch 116/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 2.0399e-04 - val_loss: 0.0011
#
# Epoch 00116: val_loss did not improve from 0.00106
# Epoch 117/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.0133e-04 - val_loss: 0.0011
#
# Epoch 00117: val_loss did not improve from 0.00106
# Epoch 118/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 2.0018e-04 - val_loss: 0.0011
#
# Epoch 00118: val_loss did not improve from 0.00106
# Epoch 119/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 2.0264e-04 - val_loss: 0.0011
#
# Epoch 00119: val_loss did not improve from 0.00106
# Epoch 120/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.9639e-04 - val_loss: 0.0011
#
# Epoch 00120: val_loss did not improve from 0.00106
# Epoch 121/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.8697e-04 - val_loss: 0.0011
#
# Epoch 00121: val_loss did not improve from 0.00106
# Epoch 122/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.8737e-04 - val_loss: 0.0011
#
# Epoch 00122: val_loss did not improve from 0.00106
# Epoch 123/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.8750e-04 - val_loss: 0.0011
#
# Epoch 00123: val_loss improved from 0.00106 to 0.00106, saving model to best_weights.h5
# Epoch 124/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.8762e-04 - val_loss: 0.0011
#
# Epoch 00124: val_loss did not improve from 0.00106
# Epoch 125/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.9148e-04 - val_loss: 0.0011
#
# Epoch 00125: val_loss improved from 0.00106 to 0.00106, saving model to best_weights.h5
# Epoch 126/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.8328e-04 - val_loss: 0.0011
#
# Epoch 00126: val_loss did not improve from 0.00106
# Epoch 127/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 1.8514e-04 - val_loss: 0.0011
#
# Epoch 00127: val_loss did not improve from 0.00106
# Epoch 128/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.7981e-04 - val_loss: 0.0011
#
# Epoch 00128: val_loss did not improve from 0.00106
# Epoch 129/150
# 1712/1712 [==============================] - 1s 507us/step - loss: 1.8321e-04 - val_loss: 0.0011
#
# Epoch 00129: val_loss did not improve from 0.00106
# Epoch 130/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.8394e-04 - val_loss: 0.0010
#
# Epoch 00130: val_loss improved from 0.00106 to 0.00104, saving model to best_weights.h5
# Epoch 131/150
# 1712/1712 [==============================] - 1s 502us/step - loss: 1.8412e-04 - val_loss: 0.0011
#
# Epoch 00131: val_loss did not improve from 0.00104
# Epoch 132/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.8065e-04 - val_loss: 0.0011
#
# Epoch 00132: val_loss did not improve from 0.00104
# Epoch 133/150
# 1712/1712 [==============================] - 1s 504us/step - loss: 1.8201e-04 - val_loss: 0.0010
#
# Epoch 00133: val_loss did not improve from 0.00104
# Epoch 134/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.8362e-04 - val_loss: 0.0011
#
# Epoch 00134: val_loss did not improve from 0.00104
# Epoch 135/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.7811e-04 - val_loss: 0.0011
#
# Epoch 00135: val_loss did not improve from 0.00104
# Epoch 136/150
# 1712/1712 [==============================] - 1s 505us/step - loss: 1.7504e-04 - val_loss: 0.0011
#
# Epoch 00136: val_loss did not improve from 0.00104
# Epoch 137/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.7925e-04 - val_loss: 0.0011
#
# Epoch 00137: val_loss did not improve from 0.00104
# Epoch 138/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.7465e-04 - val_loss: 0.0011
#
# Epoch 00138: val_loss did not improve from 0.00104
# Epoch 139/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.7680e-04 - val_loss: 0.0011
#
# Epoch 00139: val_loss did not improve from 0.00104
# Epoch 140/150
# 1712/1712 [==============================] - 1s 503us/step - loss: 1.7894e-04 - val_loss: 0.0011
#
# Epoch 00140: val_loss did not improve from 0.00104
# Epoch 141/150
# 1712/1712 [==============================] - 1s 518us/step - loss: 1.7245e-04 - val_loss: 0.0011
#
# Epoch 00141: val_loss did not improve from 0.00104
# Epoch 142/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.6967e-04 - val_loss: 0.0011
#
# Epoch 00142: val_loss did not improve from 0.00104
# Epoch 143/150
# 1712/1712 [==============================] - 1s 509us/step - loss: 1.7620e-04 - val_loss: 0.0011
#
# Epoch 00143: val_loss did not improve from 0.00104
# Epoch 144/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.7041e-04 - val_loss: 0.0011
#
# Epoch 00144: val_loss did not improve from 0.00104
# Epoch 145/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.7233e-04 - val_loss: 0.0011
#
# Epoch 00145: val_loss did not improve from 0.00104
# Epoch 146/150
# 1712/1712 [==============================] - 1s 511us/step - loss: 1.7129e-04 - val_loss: 0.0011
#
# Epoch 00146: val_loss did not improve from 0.00104
# Epoch 147/150
# 1712/1712 [==============================] - 1s 506us/step - loss: 1.6288e-04 - val_loss: 0.0011
#
# Epoch 00147: val_loss did not improve from 0.00104
# Epoch 148/150
# 1712/1712 [==============================] - 1s 513us/step - loss: 1.6697e-04 - val_loss: 0.0011
#
# Epoch 00148: val_loss did not improve from 0.00104
# Epoch 149/150
# 1712/1712 [==============================] - 1s 515us/step - loss: 1.6866e-04 - val_loss: 0.0011
#
# Epoch 00149: val_loss did not improve from 0.00104
# Epoch 150/150
# 1712/1712 [==============================] - 1s 510us/step - loss: 1.6460e-04 - val_loss: 0.0010
#
# Epoch 00150: val_loss did not improve from 0.00104

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
